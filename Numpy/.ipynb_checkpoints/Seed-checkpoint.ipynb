# %%
import numpy as np

# %% [markdown]
# ### Without seed

# %%
# Without seed (different output every run)
print("Without seed (run 1) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# Without seed (run 1) :
# randint :  [8 9 8 7 8]
# rand :  [0.48870752 0.82600982 0.0504663  0.13848048 0.01268316]
# choice :  [2 2 2 1 2]

# %%
# Without seed (different output every run)
print("Without seed (run 2) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# Without seed (run 2) :
# randint :  [2 6 7 1 5]
# rand :  [0.30650422 0.60407894 0.66305194 0.02077276 0.7714186 ]
# choice :  [1 3 3 3 1]

# %%
# Without seed (different output every run)
print("Without seed (run 3) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# Without seed (run 3) :
# randint :  [1 3 2 5 9]
# rand :  [0.59152252 0.68679991 0.61106607 0.23248492 0.80703033]
# choice :  [1 3 3 1 1]

# %%
# Without seed (different output every run)
print("Without seed (run 4) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# Without seed (run 4) :
# randint :  [3 9 6 8 8]
# rand :  [0.31147075 0.80664468 0.79913156 0.57974815 0.00465244]
# choice :  [3 1 2 1 4]

# %% [markdown]
# ### With Seed

# %%
# With seed (same output every run)
np.random.seed(42)
print("With seed (run 1 ) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# With seed (run 1 ) :
# randint :  [7 4 8 5 7]
# rand :  [0.44583275 0.09997492 0.45924889 0.33370861 0.14286682]
# choice :  [3 2 1 2 4]

# %%
# With seed (same output every run)
np.random.seed(42)
print("With seed (run 2) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# With seed (run 2) :
# randint :  [7 4 8 5 7]
# rand :  [0.44583275 0.09997492 0.45924889 0.33370861 0.14286682]
# choice :  [3 2 1 2 4]

# %%
# With seed (same output every run)
np.random.seed(42)
print("With seed (run 3) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# With seed (run 3) :
# randint :  [7 4 8 5 7]
# rand :  [0.44583275 0.09997492 0.45924889 0.33370861 0.14286682]
# choice :  [3 2 1 2 4]

# %%
# With seed (same output every run)
np.random.seed(42)
print("With seed (run 4) : ")
print("randint : ", np.random.randint(1,10,5)) # Generates 5 random integers between 1 and 10
print("rand : ", np.random.rand(5)) 
print("choice : ", np.random.choice([1,2,3,4],5))
# Out:
# With seed (run 4) :
# randint :  [7 4 8 5 7]
# rand :  [0.44583275 0.09997492 0.45924889 0.33370861 0.14286682]
# choice :  [3 2 1 2 4]

# %% [markdown]
# ### uniform and normal

# %%
print("\nuniform :", np.random.uniform(10,50,5))
print("normal :",np.random.normal(50,5,5))
# Out:
# uniform : [43.29770563 18.49356443 17.27299869 17.33618039 22.16968972]
# normal : [36.93725494 54.75184841 54.0822254  42.38062001 47.85976968]
