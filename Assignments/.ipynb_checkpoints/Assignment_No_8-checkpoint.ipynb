# %% [markdown]
# # Assignment No - 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title.
x_axis=[10,20,30,40,50,60,70,80]
y_axis=[20,40,60,80,100,120,140,160]

plt.figure(figsize=(6,4))
plt.plot(x_axis,y_axis)
plt.title("Draw a line")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
#2. Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title.
x=[1,2,3]
y=[2,4,1]

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('SampleGraph')
# Out:
# Text(0.5, 1.0, 'SampleGraph')

# %%
#3. Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.
import os
os.getcwd

plt.figure(figsize=(6,4))
x = []
y = []
with open("text.txt",'r') as file:
    for i in file:
        values = i.split()
        x.append(int(values[0]))
        y.append(int(values[1]))
plt.plot(x,y)        
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('SampleGraph')
plt.show()

# %%
#4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#Sample Financial data (fdata.csv):

df = pd.read_csv('fdata.csv')

df.plot()

plt.title('Alphabet Inc. Financial Data (Oct 3 - Oct 7, 2016)')
plt.xlabel('Date')
plt.ylabel('Price (USD)')


plt.show()

# %%
#5. Write a Python program to plot two or more lines on same plot with suitable legends of each line
x = [10, 20, 30]
y1 = [20, 40, 10]
y2 = [40, 10, 30]

plt.plot(x, y1, label='line 1')
plt.plot(x, y2, label='line 2')

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Two or more lines on same plot with suitable legends')
plt.legend()
plt.show()

# %%
#6. Write a Python program to plot two or more lines with legends, different widths and colors.
import matplotlib.pyplot as plt

x = [10, 20, 30]
y1 = [20, 40, 10]
y2 = [40, 10, 30]

# Set color and linewidth
plt.plot(x, y1, color='blue', linewidth=3, label='line1-width-3')
plt.plot(x, y2, color='red', linewidth=5, label='line2-width-5')

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Two or more lines with different widths and colors with suitable legends')
plt.legend()
plt.show()

# %%
#7. Write a Python program to plot two or more lines with different styles.

x = [10, 20, 30]
y1 = [20, 40, 10]
y2 = [40, 10, 30]


plt.plot(x, y1, color='blue', linewidth=1, label='line1-dotted', linestyle='dotted')
plt.plot(x, y2, color='red', linewidth=3, label='line2-dashed', linestyle='dashed')

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Plot with two or more lines with different styles')
plt.legend()
plt.show()

# %%
#8. Write a Python program to plot two or more lines and set the line markers.

x = [1, 4, 5, 6, 7]
y = [2, 6, 3, 6, 3]

plt.plot(x, y, color='red', linestyle='dashdot', linewidth=1, 
         marker='o', markerfacecolor='blue', markersize=12)

plt.ylim(1, 8)
plt.xlim(1, 8)

plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Display marker')
plt.show()

# %%
#9. Write a Python program to display the current axis limits values and set new axis values.
import matplotlib.pyplot as plt

x = [0,10, 20, 30, 40, 50]
y = [0,30, 60, 90, 120, 150]

plt.plot(x, y)

# Displaying current axis limits
print(f"Current axis limits: {plt.axis()}")

# Setting new axis values [xmin, xmax, ymin, ymax]
plt.axis([0, 100, 0, 200])

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Display and Set Axis Limits')

plt.show()
# Out:
# Current axis limits: (np.float64(-2.5), np.float64(52.5), np.float64(-7.5), np.float64(157.5))

# %%
#10. Write a Python program to plot quantities which have an x and y position.

x_stars = [2, 3, 5, 6, 8, 9]
y_stars = [1, 5, 10, 18, 20, 25]

x_circles = [3, 4, 7, 10]
y_circles = [5, 12, 15, 22]

plt.plot(x_stars, y_stars, 'b*', label='Stars')
plt.plot(x_circles, y_circles, 'ro', label='Circles')

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Star and Circle Quantities')
plt.legend()

plt.show()

# %%
#11. Write a Python program to plot several lines with different format styles in one command using arrays.
t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple Lines with Different Styles')

plt.show()

# %%
#12. Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.

fdata = [
    ("10-03-16", 772.559998),
    ("10-04-16", 776.429993),
    ("10-05-16", 776.469971),
    ("10-06-16", 776.859985),
    ("10-07-16", 775.080017)
]

dates, values = zip(*fdata)

plt.plot(dates, values, color='blue', marker='o')

plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing Stock Value of Alphabet Inc.')

plt.show()

# %%
#13. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with linestyle -, width .5. and color blue.

plt.plot(dates, values, color='blue', marker='o')

plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing Stock Value of Alphabet Inc.')

plt.grid(linestyle='-', linewidth='0.5', color='blue')

plt.show()

# %%
#14. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#Customized the grid lines with rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn off ticks.

plt.plot(dates, values, color='red', marker='o')

plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing Stock Value of Alphabet Inc.')

plt.minorticks_on()

plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

plt.tick_params(which='both', top=False, left=False, right=False, bottom=False, 
                labeltop=False, labelleft=True, labelright=False, labelbottom=True)

plt.show()

# %%
#15. Write a Python program to create multiple plots.

x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 8, 27, 64, 125]

plt.subplot(1, 2, 1)
plt.plot(x, y1)

plt.subplot(1, 2, 2)
plt.plot(x, y2)

plt.show()
